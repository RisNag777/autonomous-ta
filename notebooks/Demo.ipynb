# %%
from src.autonomous_ta.agent import *

# %%
agent = TextbookAgent()
# Out:
# Computing embeddings...
# Batches:   0%|          | 0/26 [00:00<?, ?it/s]
# Index for Introductory_Statistics_2e_-_WEB.pdf.json built with 827 chunks

# %%
question = "What is regression and why is it useful? What are the disadvantages of using regression?"

# %%
answer, results = agent.answer_question(question)
# Out:
# Consulting Chapters - ['12.3 The Regression Equation', '12.5 Prediction', 'Bivariate Data, Linear Regression, and Univariate Data']
# Self-evaluation: YES
# === ANSWER ===
# Regression is a statistical process used to determine the relationship between two or more variables. Specifically, it allows us to predict the value of a dependent variable (y) based on the value of an independent variable (x). In the context of linear regression, a line of best fit, or least-squares line, is calculated to approximate the relationship between the variables. This line helps in making predictions and understanding how changes in the independent variable affect the dependent variable.
#
# Regression is useful because it provides a way to model and analyze the relationships between variables, enabling predictions and insights into data trends. It can help identify patterns, assess the strength of relationships, and quantify the degree of association between variables.
#
# However, there are disadvantages to using regression. One major limitation is that data rarely fit a straight line exactly, leading to rough predictions. Additionally, regression assumes a linear relationship between the variables, which may not always be the case. If the relationship is not linear, the regression model may not accurately represent the data. Furthermore, the presence of outliers can significantly affect the regression results, leading to misleading conclusions. Lastly, regression analysis can be complex and may require careful interpretation to avoid misinterpretation of the results.
#
# === CHUNKS RETRIEVED ===
# 12.3 The Regression Equation (Page 638):
# 12.3 The Regression Equation (Page 640):
# 12.3 The Regression Equation (Page 642):
# 12.3 The Regression Equation (Page 641):
# 12.3 The Regression Equation (Page 637):
